# %%
from sklearn.datasets import make_classification

# %% [markdown]
# ## Create a Dataset

# %%
import numpy as np
x,y=make_classification(n_samples=100,n_features=2,n_informative=1,n_redundant=0,n_classes=2,n_clusters_per_class=1,random_state=41,hypercube=False,class_sep=10)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Create Scatter Plot for Dataset

# %%
plt.figure(figsize=(10,6))
plt.scatter(x[:,0],x[:,-1],c=y,cmap='winter',s=100)

# %% [markdown]
# ## Define the Funtion of Perceptron

# %%
def perceptron(x,y):
    x=np.insert(x,0,1,axis=1)
    weights=np.ones(x.shape[1])
    learning_rate=0.01
    for j in range (1000):
        j=np.random.randint(0,100)
        y_hat=step(np.dot(x[j],weights))
        weights=weights + learning_rate * (y[j]-y_hat) * x[j]
        
    return weights[0],weights[1:]

# %% [markdown]
# ## Step Function

# %%
def step(z):
    return 1 if z>0 else 0

# %% [markdown]
# ## Calling the perceptron and get intercept and coefficient

# %%
intercept,coefficient=perceptron(x,y)

# %%
print(intercept)
print(coefficient)
# Out:
# 0.9199999999999999
# [1.31389022 0.27614519]

# %% [markdown]
# ## Finds the m, b

# %%
m=-(coefficient[0]/coefficient[1])
b=-(intercept/coefficient[1])
m,b
# Out:
# (-4.757968887896652, -3.331580756401341)

# %%
x_input=np.linspace(-3,3,100)
y_input=m*x_input + b

# %% [markdown]
# ## Plot the graph.

# %%
plt.figure(figsize=(7,7))
plt.plot(x_input,y_input,color='red',linewidth=3)
plt.scatter(x[:,0],x[:,1],c=y,cmap='winter',s=100)
plt.ylim(-3,2)
# Out:
# (-3.0, 2.0)
